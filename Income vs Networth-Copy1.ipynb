# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = "ECON3-data.csv"

df = pd.read_csv(file)
print(df.head())

#Just to try more options
x = "ASSET"
y = "NETWORTH"
v = "EDUC"
b = "EDCL"
m = "INCOME"
c = "WAGEINC"

plt.scatter(x = df[m], y = df[y])
plt.title("Income based on Wages")
plt.xlabel("Income")
plt.ylabel("Networth")
# Out:
#   EDUC  NETWORTH    ASSET  HSTOCKS  OWN  DEBT2INC  EDCL   INCOME  WAGEINC
# 0    8   2201.71  3731.72        0    1  0.157130     2  9737.17  1947.43
# 1    8   2406.96  3731.72        0    1  0.136052     2  9737.17  1947.43
# 2    8   2033.79  3731.72        0    1  0.174376     2  9737.17  1947.43
# 3    8   2052.45  3731.72        0    1  0.172460     2  9737.17  1947.43
# 4    8   2257.69  3731.72        0    1  0.151382     2  9737.17  1947.43
# C:\Users\Administrador2\AppData\Local\Temp\ipykernel_16508\2592591675.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# Text(0, 0.5, 'Networth')
